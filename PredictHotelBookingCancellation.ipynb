# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the file

# %%
data=pd.read_csv("hotel_bookings.csv")

# %%
print("shape of data: ",data.shape)
print(data.hotel.nunique())
# Out:
# shape of data:  (119390, 32)
# 2

# %% [markdown]
# <b>Here 2 means- resort hotel and  city hotel<b>

# %% [markdown]
# missing value

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# cleaning the data

# %%
def data_clean():
  data.fillna(0,inplace=True)
  print(data.isnull().sum())
data_clean()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
list=['adults', 'children', 'babies']
for i in list:
  print('{} has unique values as{}'.format(i,data[i].unique()))
# Out:
# adults has unique values as[ 2  1  3  4 40 26 50 27 55  0 20  6  5 10]
# children has unique values as[ 0.  1.  2. 10.  3.]
# babies has unique values as[ 0  1  2 10  9]

# %%
pd.set_option('display.max_columns',32)
filter=(data['children']==0) & (data['adults']==0) & (data['babies']==0)
data[filter]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2224    Resort Hotel            0          1               2015
# 2409    Resort Hotel            0          0               2015
# 3181    Resort Hotel            0         36               2015
# 3684    Resort Hotel            0        165               2015
# 3708    Resort Hotel            0        165               2015
# ...              ...          ...        ...                ...
# 115029    City Hotel            0        107               2017
# 115091    City Hotel            0          1               2017
# 116251    City Hotel            0         44               2017
# 116534    City Hotel            0          2               2017
# 117087    City Hotel            0        170               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2224              October                        41
# 2409              October                        42
# ...

# %%
datas=data[~filter]
datas
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
country_wise_data=datas[datas['is_canceled']==0]['country'].value_counts().reset_index()
country_wise_data.columns=['country','no of guests']
country_wise_data
# Out:
#     country  no of guests
# 0       PRT         20977
# 1       GBR          9668
# 2       FRA          8468
# 3       ESP          6383
# 4       DEU          6067
# ..      ...           ...
# 161     BHR             1
# 162     DJI             1
# 163     MLI             1
# 164     NPL             1
# 165     FRO             1
#
# [166 rows x 2 columns]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install folium

# %%
import folium
from folium.plugins import HeatMap
basemap=folium.Map()

# %%
#!pip install plotly

# %%
import plotly.express as px

# %%
data2=datas[datas['is_canceled']==0]

# %%
data2.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='reserved_room_type',y='adr',hue='hotel',data=data2)
plt.title('Price of room types per night and per person')
plt.xlabel('Room type')
plt.ylabel('Price in Euro')
plt.legend()
plt.show()

# %% [markdown]
# price per night vary over year

# %%
data_resort=datas[(datas['hotel']=='Resort Hotel') & (datas['is_canceled']==0)]
data_city=datas[(datas['hotel']=='City Hotel') & (datas['is_canceled']==0)]

# %%
data_resort
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
resort_hotel=data_resort.groupby(['arrival_date_month'])['adr'].mean().reset_index()
resort_hotel
# Out:
#    arrival_date_month         adr
# 0               April   75.867816
# 1              August  181.205892
# 2            December   68.410104
# 3            February   54.147478
# 4             January   48.761125
# 5                July  150.122528
# 6                June  107.974850
# 7               March   57.056838
# 8                 May   76.657558
# 9            November   48.706289
# 10            October   61.775449
# 11          September   96.416860

# %%
city_hotel=data_city.groupby(['arrival_date_month'])['adr'].mean().reset_index()
city_hotel
# Out:
#    arrival_date_month         adr
# 0               April  111.962267
# 1              August  118.674598
# 2            December   88.401855
# 3            February   86.520062
# 4             January   82.330983
# 5                July  115.818019
# 6                June  117.874360
# 7               March   90.658533
# 8                 May  120.669827
# 9            November   86.946592
# 10            October  102.004672
# 11          September  112.776582

# %%
final=resort_hotel.merge(city_hotel,on='arrival_date_month')
final.columns=['months','price_for_resort','price_for_city_hotel']
final
# Out:
#        months  price_for_resort  price_for_city_hotel
# 0       April         75.867816            111.962267
# 1      August        181.205892            118.674598
# 2    December         68.410104             88.401855
# 3    February         54.147478             86.520062
# 4     January         48.761125             82.330983
# 5        July        150.122528            115.818019
# 6        June        107.974850            117.874360
# 7       March         57.056838             90.658533
# 8         May         76.657558            120.669827
# 9    November         48.706289             86.946592
# 10    October         61.775449            102.004672
# 11  September         96.416860            112.776582

# %%
#!pip install sort-dataframeby-monthorweek

# %%
#!pip install sorted-months-weekdays

# %%
import sort_dataframeby_monthorweek as sd

# %%
def sort_data(data,colname):
  return sd.Sort_Dataframeby_Month(data,colname)

# %% [markdown]
# <b>This clearly shows that the prices in the Resort hotel are much higher during the summer (no surprise here)., The price of the city hotel varies less and is most expensive during spring and autumn.<b>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Analyzing of hotel demands on which most busy month and guests are high?

# %%
data_resort.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
rush_resort=data_resort['arrival_date_month'].value_counts().reset_index()
rush_resort.columns=['months','no of guests']
rush_resort
# Out:
#        months  no of guests
# 0      August          3257
# 1        July          3137
# 2     October          2575
# 3       March          2571
# 4       April          2550
# 5         May          2535
# 6    February          2308
# 7   September          2102
# 8        June          2037
# 9    December          2014
# 10   November          1975
# 11    January          1866

# %%
rush_city=data_city['arrival_date_month'].value_counts().reset_index()
rush_city.columns=['months','no of guests']
rush_city
# Out:
#        months  no of guests
# 0      August          5367
# 1        July          4770
# 2         May          4568
# 3        June          4358
# 4     October          4326
# 5   September          4283
# 6       March          4049
# 7       April          4010
# 8    February          3051
# 9    November          2676
# 10   December          2377
# 11    January          2249

# %%
final_rush=rush_resort.merge(rush_city,on='months')
final_rush.columns=['month','no of guest in resort','no of guest in city']
final_rush
# Out:
#         month  no of guest in resort  no of guest in city
# 0      August                   3257                 5367
# 1        July                   3137                 4770
# 2     October                   2575                 4326
# 3       March                   2571                 4049
# 4       April                   2550                 4010
# 5         May                   2535                 4568
# 6    February                   2308                 3051
# 7   September                   2102                 4283
# 8        June                   2037                 4358
# 9    December                   2014                 2377
# 10   November                   1975                 2676
# 11    January                   1866                 2249

# %%
final_rush=sort_data(final_rush,'month')
final_rush
# Out:
#         month  no of guest in resort  no of guest in city
# 0     January                   1866                 2249
# 1    February                   2308                 3051
# 2       March                   2571                 4049
# 3       April                   2550                 4010
# 4         May                   2535                 4568
# 5        June                   2037                 4358
# 6        July                   3137                 4770
# 7      August                   3257                 5367
# 8   September                   2102                 4283
# 9     October                   2575                 4326
# 10   November                   1975                 2676
# 11   December                   2014                 2377

# %% [markdown]
# <b>Conclusion
#  The City hotel has more guests during spring and autumn, when the prices are also highest.
# In July and August there are less visitors, although prices are lower.
#
# Guest numbers for the Resort hotel go down slighty from June to September, which is also when the prices are highest.
# Both hotels have the fewest guests during the winter.</b>

# %% [markdown]
# Selecting important features using machine learning

# %%
datas.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
datas.corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.292876           0.016622
# lead_time                          0.292876   1.000000           0.040334
# arrival_date_year                  0.016622   0.040334           1.000000
# arrival_date_week_number           0.008315   0.127046          -0.540373
# arrival_date_day_of_month         -0.005948   0.002306          -0.000121
# stays_in_weekend_nights           -0.001323   0.085985           0.021694
# stays_in_week_nights               0.025542   0.166892           0.031203
# adults                             0.058182   0.117575           0.030266
# children                           0.004851  -0.037878           0.054710
# babies                            -0.032569  -0.021003          -0.013192
# is_repeated_guest                 -0.083745  -0.123209           0.010281
# previous_cancellations             0.110139   0.086025          -0.119905
# ...

# %%
co_relation=datas.corr()['is_canceled']
co_relation
# Out:
# is_canceled                       1.000000
# lead_time                         0.292876
# arrival_date_year                 0.016622
# arrival_date_week_number          0.008315
# arrival_date_day_of_month        -0.005948
# stays_in_weekend_nights          -0.001323
# stays_in_week_nights              0.025542
# adults                            0.058182
# children                          0.004851
# babies                           -0.032569
# is_repeated_guest                -0.083745
# previous_cancellations            0.110139
# previous_bookings_not_canceled   -0.057365
# booking_changes                  -0.144832
# agent                            -0.046770
# company                          -0.083594
# days_in_waiting_list              0.054301
# adr                               0.046492
# required_car_parking_spaces      -0.195701
# total_of_special_requests        -0.234877
# Name: is_canceled, dtype: float64

# %%
co_relation.abs()
# Out:
# is_canceled                       1.000000
# lead_time                         0.292876
# arrival_date_year                 0.016622
# arrival_date_week_number          0.008315
# arrival_date_day_of_month         0.005948
# stays_in_weekend_nights           0.001323
# stays_in_week_nights              0.025542
# adults                            0.058182
# children                          0.004851
# babies                            0.032569
# is_repeated_guest                 0.083745
# previous_cancellations            0.110139
# previous_bookings_not_canceled    0.057365
# booking_changes                   0.144832
# agent                             0.046770
# company                           0.083594
# days_in_waiting_list              0.054301
# adr                               0.046492
# required_car_parking_spaces       0.195701
# total_of_special_requests         0.234877
# Name: is_canceled, dtype: float64

# %%
co_relation.abs().sort_values(ascending=False)
# Out:
# is_canceled                       1.000000
# lead_time                         0.292876
# total_of_special_requests         0.234877
# required_car_parking_spaces       0.195701
# booking_changes                   0.144832
# previous_cancellations            0.110139
# is_repeated_guest                 0.083745
# company                           0.083594
# adults                            0.058182
# previous_bookings_not_canceled    0.057365
# days_in_waiting_list              0.054301
# agent                             0.046770
# adr                               0.046492
# babies                            0.032569
# stays_in_week_nights              0.025542
# arrival_date_year                 0.016622
# arrival_date_week_number          0.008315
# arrival_date_day_of_month         0.005948
# children                          0.004851
# stays_in_weekend_nights           0.001323
# Name: is_canceled, dtype: float64

# %%
datas.groupby('is_canceled')['reservation_status'].value_counts()
# Out:
# is_canceled  reservation_status
# 0            Check-Out             75011
# 1            Canceled              42993
#              No-Show                1206
# Name: reservation_status, dtype: int64

# %% [markdown]
# #fetching numerical and categorical columns

# %%
list_not=['days_in_waiting_list','arrival_date_year']
list_not
# Out:
# ['days_in_waiting_list', 'arrival_date_year']

# %%
num_features=[col for col in datas.columns if datas[col].dtype!='O' and col not in list_not]
num_features
# Out:
# ['is_canceled',
#  'lead_time',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'agent',
#  'company',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests']

# %%
datas.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
cat_not=['arrival_date_year','assigned_room_type','booking_changes','reservation_status','country']

# %%
cat_features=[col for col in datas.columns if datas[col].dtype=='O' and col not in cat_not]

# %%
cat_features
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status_date']

# %% [markdown]
# <i><h2>Extracting Derived features such as date </h2></i>

# %%
data_cat=datas[cat_features]
data_cat.head()
# Out:
#           hotel arrival_date_month meal market_segment distribution_channel  \
# 0  Resort Hotel               July   BB         Direct               Direct
# 1  Resort Hotel               July   BB         Direct               Direct
# 2  Resort Hotel               July   BB         Direct               Direct
# 3  Resort Hotel               July   BB      Corporate            Corporate
# 4  Resort Hotel               July   BB      Online TA                TA/TO
#
#   reserved_room_type deposit_type customer_type reservation_status_date
# 0                  C   No Deposit     Transient                7/1/2015
# 1                  C   No Deposit     Transient                7/1/2015
# 2                  A   No Deposit     Transient                7/2/2015
# 3                  A   No Deposit     Transient                7/2/2015
# 4                  A   No Deposit     Transient                7/3/2015

# %%
data_cat.dtypes
# Out:
# hotel                      object
# arrival_date_month         object
# meal                       object
# market_segment             object
# distribution_channel       object
# reserved_room_type         object
# deposit_type               object
# customer_type              object
# reservation_status_date    object
# dtype: object

# %%
data_cat['reservation_status_date']=pd.to_datetime(data_cat['reservation_status_date'])

# %%
data_cat
# Out:
#                hotel arrival_date_month meal market_segment  \
# 0       Resort Hotel               July   BB         Direct
# 1       Resort Hotel               July   BB         Direct
# 2       Resort Hotel               July   BB         Direct
# 3       Resort Hotel               July   BB      Corporate
# 4       Resort Hotel               July   BB      Online TA
# ...              ...                ...  ...            ...
# 119385    City Hotel             August   BB  Offline TA/TO
# 119386    City Hotel             August   BB      Online TA
# 119387    City Hotel             August   BB      Online TA
# 119388    City Hotel             August   BB      Online TA
# 119389    City Hotel             August   HB      Online TA
#
#        distribution_channel reserved_room_type deposit_type customer_type  \
# 0                    Direct                  C   No Deposit     Transient
# 1                    Direct                  C   No Deposit     Transient
# ...

# %%
data_cat['year']=data_cat['reservation_status_date'].dt.year
data_cat['month']=data_cat['reservation_status_date'].dt.month
data_cat['day']=data_cat['reservation_status_date'].dt.day

# %%
data_cat.head()
# Out:
#           hotel arrival_date_month meal market_segment distribution_channel  \
# 0  Resort Hotel               July   BB         Direct               Direct
# 1  Resort Hotel               July   BB         Direct               Direct
# 2  Resort Hotel               July   BB         Direct               Direct
# 3  Resort Hotel               July   BB      Corporate            Corporate
# 4  Resort Hotel               July   BB      Online TA                TA/TO
#
#   reserved_room_type deposit_type customer_type reservation_status_date  year  \
# 0                  C   No Deposit     Transient              2015-07-01  2015
# 1                  C   No Deposit     Transient              2015-07-01  2015
# 2                  A   No Deposit     Transient              2015-07-02  2015
# 3                  A   No Deposit     Transient              2015-07-02  2015
# 4                  A   No Deposit     Transient              2015-07-03  2015
#
#    month  day
# 0      7    1
# ...

# %%
data_cat.drop('reservation_status_date',axis=1,inplace=True)

# %%
data_cat.head()
# Out:
#           hotel arrival_date_month meal market_segment distribution_channel  \
# 0  Resort Hotel               July   BB         Direct               Direct
# 1  Resort Hotel               July   BB         Direct               Direct
# 2  Resort Hotel               July   BB         Direct               Direct
# 3  Resort Hotel               July   BB      Corporate            Corporate
# 4  Resort Hotel               July   BB      Online TA                TA/TO
#
#   reserved_room_type deposit_type customer_type  year  month  day
# 0                  C   No Deposit     Transient  2015      7    1
# 1                  C   No Deposit     Transient  2015      7    1
# 2                  A   No Deposit     Transient  2015      7    2
# 3                  A   No Deposit     Transient  2015      7    2
# 4                  A   No Deposit     Transient  2015      7    3

# %%
data_cat['cancellation']=data['is_canceled']
data_cat.head()
# Out:
#           hotel arrival_date_month meal market_segment distribution_channel  \
# 0  Resort Hotel               July   BB         Direct               Direct
# 1  Resort Hotel               July   BB         Direct               Direct
# 2  Resort Hotel               July   BB         Direct               Direct
# 3  Resort Hotel               July   BB      Corporate            Corporate
# 4  Resort Hotel               July   BB      Online TA                TA/TO
#
#   reserved_room_type deposit_type customer_type  year  month  day  \
# 0                  C   No Deposit     Transient  2015      7    1
# 1                  C   No Deposit     Transient  2015      7    1
# 2                  A   No Deposit     Transient  2015      7    2
# 3                  A   No Deposit     Transient  2015      7    2
# 4                  A   No Deposit     Transient  2015      7    3
#
#    cancellation
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
data_cat['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %% [markdown]
# <i><h2>Handling categorical values</i></h2>

# %% [markdown]
# <i>converting categorical data into numerical data using mean encoding technique</i>

# %%
cols=data_cat.columns[0:8]
cols
# Out:
# Index(['hotel', 'arrival_date_month', 'meal', 'market_segment',
#        'distribution_channel', 'reserved_room_type', 'deposit_type',
#        'customer_type'],
#       dtype='object')

# %%
data_cat.groupby(['hotel'])['cancellation'].mean().reset_index()
# Out:
#           hotel  cancellation
# 0    City Hotel      0.417859
# 1  Resort Hotel      0.277674

# %%
for col in cols:
    print(data_cat.groupby([col])['cancellation'].mean())
    print('************************************************************')
# Out:
# hotel
# City Hotel      0.417859
# Resort Hotel    0.277674
# Name: cancellation, dtype: float64
# ************************************************************
# arrival_date_month
# April        0.407835
# August       0.377823
# December     0.350348
# February     0.334451
# January      0.305016
# July         0.374644
# June         0.414860
# March        0.322277
# May          0.397029
# November     0.313100
# October      0.380910
# September    0.391905
# Name: cancellation, dtype: float64
# ************************************************************
# meal
# BB           0.374106
# FB           0.598997
# HB           0.344653
# SC           0.374064
# Undefined    0.244654
# Name: cancellation, dtype: float64
# ************************************************************
# market_segment
# Aviation         0.221277
# Complementary    0.122253
# Corporate        0.187618
# Direct           0.153712
# Groups           0.611086
# Offline TA/TO    0.343313
# ...

# %%
for col in cols:
    dict=data_cat.groupby([col])['cancellation'].mean().to_dict()
    data_cat[col]=data_cat[col].map(dict)

# %%
data_cat.head()
# Out:
#       hotel  arrival_date_month      meal  market_segment  \
# 0  0.277674            0.374644  0.374106        0.153712
# 1  0.277674            0.374644  0.374106        0.153712
# 2  0.277674            0.374644  0.374106        0.153712
# 3  0.277674            0.374644  0.374106        0.187618
# 4  0.277674            0.374644  0.374106        0.367590
#
#    distribution_channel  reserved_room_type  deposit_type  customer_type  \
# 0              0.174868            0.330827       0.28402       0.407864
# 1              0.174868            0.330827       0.28402       0.407864
# 2              0.174868            0.391567       0.28402       0.407864
# 3              0.220568            0.391567       0.28402       0.407864
# 4              0.410598            0.391567       0.28402       0.407864
#
#    year  month  day  cancellation
# 0  2015      7    1             0
# 1  2015      7    1             0
# 2  2015      7    2             0
# 3  2015      7    2             0
# ...

# %%
dataframe=pd.concat([data_cat,datas[num_features]],axis=1)
dataframe.head()
# Out:
#       hotel  arrival_date_month      meal  market_segment  \
# 0  0.277674            0.374644  0.374106        0.153712
# 1  0.277674            0.374644  0.374106        0.153712
# 2  0.277674            0.374644  0.374106        0.153712
# 3  0.277674            0.374644  0.374106        0.187618
# 4  0.277674            0.374644  0.374106        0.367590
#
#    distribution_channel  reserved_room_type  deposit_type  customer_type  \
# 0              0.174868            0.330827       0.28402       0.407864
# 1              0.174868            0.330827       0.28402       0.407864
# 2              0.174868            0.391567       0.28402       0.407864
# 3              0.220568            0.391567       0.28402       0.407864
# 4              0.410598            0.391567       0.28402       0.407864
#
#    year  month  day  cancellation  is_canceled  lead_time  \
# 0  2015      7    1             0            0        342
# ...

# %%
dataframe.drop('is_canceled',axis=1,inplace=True)

# %%
dataframe.head()
# Out:
#       hotel  arrival_date_month      meal  market_segment  \
# 0  0.277674            0.374644  0.374106        0.153712
# 1  0.277674            0.374644  0.374106        0.153712
# 2  0.277674            0.374644  0.374106        0.153712
# 3  0.277674            0.374644  0.374106        0.187618
# 4  0.277674            0.374644  0.374106        0.367590
#
#    distribution_channel  reserved_room_type  deposit_type  customer_type  \
# 0              0.174868            0.330827       0.28402       0.407864
# 1              0.174868            0.330827       0.28402       0.407864
# 2              0.174868            0.391567       0.28402       0.407864
# 3              0.220568            0.391567       0.28402       0.407864
# 4              0.410598            0.391567       0.28402       0.407864
#
#    year  month  day  cancellation  lead_time  arrival_date_week_number  \
# 0  2015      7    1             0        342                        27
# ...

# %% [markdown]
# <i><h2>Handling Outliers</h2></i>

# %%
sns.distplot(dataframe['lead_time'])
# Out:
# <AxesSubplot:xlabel='lead_time', ylabel='Density'>

# %%
import numpy as np

def handle_outlier(col):
    dataframe[col]=np.log1p(dataframe[col])

# %%
handle_outlier('lead_time')

# %%
sns.distplot(dataframe['lead_time'].dropna())
# Out:
# <AxesSubplot:xlabel='lead_time', ylabel='Density'>

# %%
sns.distplot(dataframe['adr'])
# Out:
# <AxesSubplot:xlabel='adr', ylabel='Density'>

# %%
handle_outlier('adr')

# %%
sns.distplot(dataframe['adr'].dropna())
# Out:
# <AxesSubplot:xlabel='adr', ylabel='Density'>

# %% [markdown]
# <i><h2>Selecting important features</h2></i>

# %%
dataframe.isnull().sum()
# Out:
# hotel                             0
# arrival_date_month                0
# meal                              0
# market_segment                    0
# distribution_channel              0
# reserved_room_type                0
# deposit_type                      0
# customer_type                     0
# year                              0
# month                             0
# day                               0
# cancellation                      0
# lead_time                         0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# agent                             0
# company                           0
# ...

# %%
dataframe.dropna(inplace=True)

# %%
dataframe=dataframe.drop('company',axis=1)
dataframe=dataframe.drop('arrival_date_week_number',axis=1)
dataframe=dataframe.drop('arrival_date_day_of_month',axis=1)

# %%
y=dataframe['cancellation']
x=dataframe.drop('cancellation',axis=1)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
feature_sel_model=SelectFromModel(Lasso(alpha=0.005,random_state=0)) # more alpha i,e, 1 less no of feature selected

# %%
feature_sel_model.fit(x,y)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
feature_sel_model.get_support()
# Out:
# array([False, False, False, False, False, False,  True, False,  True,
#         True,  True,  True, False, False,  True,  True, False, False,
#         True,  True,  True,  True,  True,  True,  True])

# %%
cols=x.columns
cols
# Out:
# Index(['hotel', 'arrival_date_month', 'meal', 'market_segment',
#        'distribution_channel', 'reserved_room_type', 'deposit_type',
#        'customer_type', 'year', 'month', 'day', 'lead_time',
#        'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
#        'babies', 'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes', 'agent', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests'],
#       dtype='object')

# %%
selected_feat=cols[feature_sel_model.get_support()]

# %%
print('total_features {}'.format(x.shape[1]))
print('selected_features {}'.format(len(selected_feat)))
# Out:
# total_features 25
# selected_features 14

# %%
selected_feat
# Out:
# Index(['deposit_type', 'year', 'month', 'day', 'lead_time', 'adults',
#        'children', 'previous_cancellations', 'previous_bookings_not_canceled',
#        'booking_changes', 'agent', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests'],
#       dtype='object')

# %%
x=x[selected_feat]

# %% [markdown]
# <i><h2>Applying Machine Learning Algorithm </h2></i>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# <i><h3></i></h3>

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[15820,  2864],
#        [ 4460,  6659]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7542529275576284

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(model,x,y,cv=10)

# %%
score.mean()
# Out:
# 0.7357918812833255

# %%
#pip install xgboost

# %% [markdown]
# <i>As it is seen there is not so accurate prediction</i>

# %% [markdown]
# <i><h3>Appliying multiple algorithm on the model and checking its accuracy</h3></i>

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# %%
models = []
models.append(('LogisticRegression', LogisticRegression()))
models.append(('Naive Bayes',GaussianNB()))
models.append(('RandomForest', RandomForestClassifier()))
models.append(('Decision Tree', DecisionTreeClassifier()))
models.append(('KNN', KNeighborsClassifier(n_neighbors = 5)))
models.append(('XGBClassifier', XGBClassifier()))

# %%
for name, model in models:
    print(name)
    model.fit(x_train, y_train)
    
    # Make predictions.
    predictions = model.predict(x_test)

    # Compute the error.
    from sklearn.metrics import confusion_matrix
    print(confusion_matrix(predictions, y_test))

    from sklearn.metrics import accuracy_score
    print(accuracy_score(predictions,y_test))
    print('\n')
# Out:
# LogisticRegression
# [[15820  4460]
#  [ 2864  6659]]
# 0.7542529275576284
#
#
# Naive Bayes
# [[8789 1314]
#  [9895 9805]]
# 0.6238969231285441
#
#
# RandomForest
# [[18010  2014]
#  [  674  9105]]
# 0.909807737476093
#
#
# Decision Tree
# [[16615  1913]
#  [ 2069  9206]]
# 0.8663892896688253
#
#
# KNN
# [[17190  2632]
#  [ 1494  8487]]
# 0.8615575613193303
#
#
# XGBClassifier
# [13:56:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [[17800  2629]
#  [  884  8490]]
# 0.8821259604737778

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
pred=model.predict(x_test)

# %%
accuracy_score(pred,y_test)
# Out:
# 0.909103110425125

# %%
x_test.head()
# Out:
#        deposit_type  year  month  day  lead_time  adults  children  \
# 28504       0.28402  2016     10    5   5.837730       2       0.0
# 17997       0.28402  2016      1   22   0.000000       1       0.0
# 41204       0.28402  2015      7    6   3.688879       2       0.0
# 94418       0.28402  2016      8    4   5.267858       2       0.0
# 92948       0.28402  2017      1   30   3.044522       1       0.0
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 28504                       0                               0
# 17997                       1                               7
# 41204                       0                               0
# 94418                       0                               0
# 92948                       0                               7
#
#        booking_changes  agent       adr  required_car_parking_spaces  \
# 28504                1  201.0  3.768153                            0
# ...

# %%
x_test.dtypes
# Out:
# deposit_type                      float64
# year                                int64
# month                               int64
# day                                 int64
# lead_time                         float64
# adults                              int64
# children                          float64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# agent                             float64
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# dtype: object

# %%
deposit_type=float(input("Enter deposit type: "))
year=int(input("Enter year"))
month=int(input("Enter month: "))
day=int(input("Enter day: "))
lead_time=float(input("Enter lead_time: "))
adults=int(input("Enter number of adults= "))
children=float(input("Enter number of children: "))
previous_cancellations=int(input("Enter number of previous cancellations: "))
previous_bookings_not_canceled=int(input("Enter number of previous_bookings_not_canceled: "))
booking_changes=int(input("Enter number of changes done in booking: "))
agent=float(input("Enter agent id: "))
adr=float(input("Enter adr: "))
required_car_parking_spaces=int(input("Enter number of required_car_parking_spaces: "))
total_of_special_requests=int(input("Enter any number od special requests: "))

# %%
x_test.columns
# Out:
# Index(['deposit_type', 'year', 'month', 'day', 'lead_time', 'adults',
#        'children', 'previous_cancellations', 'previous_bookings_not_canceled',
#        'booking_changes', 'agent', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests'],
#       dtype='object')

# %%
mydata=[[deposit_type, year, month, day, lead_time, adults,
       children, previous_cancellations, previous_bookings_not_canceled,
       booking_changes, agent, adr, required_car_parking_spaces,
       total_of_special_requests]]

# %%
mydata
# Out:
# [[0.28154, 2019, 5, 12, 3.555, 4, 5.0, 2, 3, 1, 2.0, 3.87666, 6, 2]]

# %%
mydata_predict=model.predict(mydata)

# %%
if mydata_predict==0:
   print("No, Ticket will not be canceled.")
else:
    print("Yes, Ticket will cancel.")
# Out:
# No, Ticket will not be canceled.

# %% [markdown]
# lead_time= Number of days that elapsed between the entering date of the booking into the PMS and the arrival date<br>
# adr=Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
